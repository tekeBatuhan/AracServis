-- %% [markdown]
-- # [AracServisDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [AracServisDB]    Script Date: 27.10.2023 15:02:30 ******/
CREATE DATABASE [AracServisDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'AracServisDB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\AracServisDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'AracServisDB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\AracServisDB_log.ldf' , SIZE = 73728KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [AracServisDB] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [AracServisDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [AracServisDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [AracServisDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [AracServisDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [AracServisDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [AracServisDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [AracServisDB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [AracServisDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [AracServisDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [AracServisDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [AracServisDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [AracServisDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [AracServisDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [AracServisDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [AracServisDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [AracServisDB] SET  DISABLE_BROKER 
GO
ALTER DATABASE [AracServisDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [AracServisDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [AracServisDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [AracServisDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [AracServisDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [AracServisDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [AracServisDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [AracServisDB] SET RECOVERY FULL 
GO
ALTER DATABASE [AracServisDB] SET  MULTI_USER 
GO
ALTER DATABASE [AracServisDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [AracServisDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [AracServisDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [AracServisDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [AracServisDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [AracServisDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'AracServisDB', N'ON'
GO
ALTER DATABASE [AracServisDB] SET QUERY_STORE = ON
GO
ALTER DATABASE [AracServisDB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[AracBilgi]

-- %%
USE [AracServisDB]
GO

-- %%
/****** Object:  Table [dbo].[AracBilgi]    Script Date: 27.10.2023 15:02:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AracBilgi](
	[aracBilgiID] [int] IDENTITY(1,1) NOT NULL,
	[marka] [nvarchar](50) NULL,
	[model] [nvarchar](50) NULL,
	[sasiNo] [nvarchar](50) NULL,
	[plaka] [nvarchar](50) NULL,
	[musteriID] [int] NOT NULL,
 CONSTRAINT [PK_AracBilgi] PRIMARY KEY CLUSTERED 
(
	[aracBilgiID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Islem]

-- %%
/****** Object:  Table [dbo].[Islem]    Script Date: 27.10.2023 15:02:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Islem](
	[islemID] [int] IDENTITY(1,1) NOT NULL,
	[islemTurID] [int] NULL,
	[girisTarihi] [smalldatetime] NULL,
	[cikisTarihi] [smalldatetime] NULL,
	[aciklama] [nvarchar](max) NULL,
	[aracBilgiID] [int] NULL,
 CONSTRAINT [PK_İslem] PRIMARY KEY CLUSTERED 
(
	[islemID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[IslemTur]

-- %%
/****** Object:  Table [dbo].[IslemTur]    Script Date: 27.10.2023 15:02:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[IslemTur](
	[islemTurID] [int] IDENTITY(1,1) NOT NULL,
	[ad] [nvarchar](500) NULL,
	[suresi] [nvarchar](50) NULL,
	[fiyat] [money] NULL,
 CONSTRAINT [PK_İslemTurID] PRIMARY KEY CLUSTERED 
(
	[islemTurID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Kullanici]

-- %%
/****** Object:  Table [dbo].[Kullanici]    Script Date: 27.10.2023 15:02:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Kullanici](
	[kullaniciID] [int] IDENTITY(1,1) NOT NULL,
	[ad] [nvarchar](50) NULL,
	[soyad] [nvarchar](50) NULL,
	[eposta] [nvarchar](50) NULL,
	[sifre] [nvarchar](50) NULL,
	[unvanID] [int] NOT NULL,
	[telefon] [nvarchar](50) NULL,
	[adres] [nvarchar](500) NULL,
	[cinsiyet] [nvarchar](50) NULL,
	[kimlikNo] [nvarchar](11) NULL,
 CONSTRAINT [PK_Kullanici] PRIMARY KEY CLUSTERED 
(
	[kullaniciID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[KullaniciIslem]

-- %%
/****** Object:  Table [dbo].[KullaniciIslem]    Script Date: 27.10.2023 15:02:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[KullaniciIslem](
	[islemID] [int] NULL,
	[kullaniciID] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Musteri]

-- %%
/****** Object:  Table [dbo].[Musteri]    Script Date: 27.10.2023 15:02:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Musteri](
	[musteriID] [int] IDENTITY(1,1) NOT NULL,
	[ad] [nvarchar](50) NULL,
	[soyad] [nvarchar](50) NULL,
	[telefon] [nvarchar](50) NULL,
 CONSTRAINT [PK_Musteri] PRIMARY KEY CLUSTERED 
(
	[musteriID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Unvan]

-- %%
/****** Object:  Table [dbo].[Unvan]    Script Date: 27.10.2023 15:02:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Unvan](
	[unvanID] [int] IDENTITY(1,1) NOT NULL,
	[ad] [nvarchar](50) NULL,
 CONSTRAINT [PK_Yetki] PRIMARY KEY CLUSTERED 
(
	[unvanID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_AracBilgi_Musteri]

-- %%
ALTER TABLE [dbo].[AracBilgi]  WITH CHECK ADD  CONSTRAINT [FK_AracBilgi_Musteri] FOREIGN KEY([musteriID])
REFERENCES [dbo].[Musteri] ([musteriID])
GO
ALTER TABLE [dbo].[AracBilgi] CHECK CONSTRAINT [FK_AracBilgi_Musteri]
GO

-- %% [markdown]
-- # [FK_Islem_AracBilgi]

-- %%
ALTER TABLE [dbo].[Islem]  WITH CHECK ADD  CONSTRAINT [FK_Islem_AracBilgi] FOREIGN KEY([aracBilgiID])
REFERENCES [dbo].[AracBilgi] ([aracBilgiID])
GO
ALTER TABLE [dbo].[Islem] CHECK CONSTRAINT [FK_Islem_AracBilgi]
GO

-- %% [markdown]
-- # [FK_İslem_İslemTurID]

-- %%
ALTER TABLE [dbo].[Islem]  WITH CHECK ADD  CONSTRAINT [FK_İslem_İslemTurID] FOREIGN KEY([islemTurID])
REFERENCES [dbo].[IslemTur] ([islemTurID])
GO
ALTER TABLE [dbo].[Islem] CHECK CONSTRAINT [FK_İslem_İslemTurID]
GO

-- %% [markdown]
-- # [FK_Kullanici_Yetki]

-- %%
ALTER TABLE [dbo].[Kullanici]  WITH CHECK ADD  CONSTRAINT [FK_Kullanici_Yetki] FOREIGN KEY([unvanID])
REFERENCES [dbo].[Unvan] ([unvanID])
GO
ALTER TABLE [dbo].[Kullanici] CHECK CONSTRAINT [FK_Kullanici_Yetki]
GO

-- %% [markdown]
-- # [FK_KullaniciIslem_Islem]

-- %%
ALTER TABLE [dbo].[KullaniciIslem]  WITH CHECK ADD  CONSTRAINT [FK_KullaniciIslem_Islem] FOREIGN KEY([islemID])
REFERENCES [dbo].[Islem] ([islemID])
GO
ALTER TABLE [dbo].[KullaniciIslem] CHECK CONSTRAINT [FK_KullaniciIslem_Islem]
GO

-- %% [markdown]
-- # [FK_KullaniciIslem_Kullanici]

-- %%
ALTER TABLE [dbo].[KullaniciIslem]  WITH CHECK ADD  CONSTRAINT [FK_KullaniciIslem_Kullanici] FOREIGN KEY([kullaniciID])
REFERENCES [dbo].[Kullanici] ([kullaniciID])
GO
ALTER TABLE [dbo].[KullaniciIslem] CHECK CONSTRAINT [FK_KullaniciIslem_Kullanici]
GO

-- %% [markdown]
-- # [AracServisDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [AracServisDB] SET  READ_WRITE 
GO
